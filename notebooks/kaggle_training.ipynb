# %% [markdown]
# # Face Mask Detection - Model Training
# This notebook runs the modernized training pipeline for Face Mask Detection using ResNet152.
#
# ## 1. Setup Environment
# We need to install specific dependencies and ensure we are in the right directory.

# %%
# Install dependencies
# !pip install -q pyyaml matplotlib seaborn scikit-learn

# Clone or Navigate to your project directory
# If using Kaggle Datasets, make sure to adjust paths in config.yaml
import os
print(f"Current Directory: {os.getcwd()}")
print(f"Contents: {os.listdir()}")

# %% [markdown]
# ## 2. Run Training Pipeline
# We will run the training script which uses the settings in `config.yaml`.

# %%
# %load_ext autoreload
# %autoreload 2

from src.pipelines.model_training import train_pipeline

# Run the pipeline
train_pipeline()
